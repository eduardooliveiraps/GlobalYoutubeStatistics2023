# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df = pd.read_csv("../data/supermarket_sales.csv")

# %% [markdown]
# # Data Understanding

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# 75%               4.761905e+00     22.445250     8.50000
# max               4.761905e+00     49.650000    10.00000

# %% [markdown]
# # Data Preperation

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
df['Time'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.rename(columns={'cogs':'COGS'})
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date                Time      Payment    COGS  \
# 0     1/5/2019 2023-08-21 13:08:00      Ewallet  522.83
# 1     3/8/2019 2023-08-21 10:29:00         Cash   76.40
# 2     3/3/2019 2023-08-21 13:23:00  Credit card  324.31
# 3    1/27/2019 2023-08-21 20:33:00      Ewallet  465.76
# 4     2/8/2019 2023-08-21 10:37:00      Ewallet  604.17
# ..         ...                 ...          ...     ...
# 995  1/29/2019 2023-08-21 13:46:00      Ewallet   40.35
# 996   3/2/2019 2023-08-21 17:16:00      Ewallet  973.80
# 997   2/9/2019 2023-08-21 13:22:00         Cash   31.84
# 998  2/22/2019 2023-08-21 15:33:00         Cash   65.82
# 999  2/18/2019 2023-08-21 13:28:00         Cash  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ..                       ...           ...     ...
# 995                 4.761905        2.0175     6.2
# 996                 4.761905       48.6900     4.4
# 997                 4.761905        1.5920     7.7
# 998                 4.761905        3.2910     4.1
# 999                 4.761905       30.9190     6.6
#
# [1000 rows x 17 columns]

# %% [markdown]
# # Dataset Analysis

# %% [markdown]
# ##### Question 1: What is the total revenue for the entire dataset?

# %%
print(f"Total revenue: {round(df['gross income'].sum(),2)} USD")
# Out:
# Total revenue: 15379.37 USD

# %% [markdown]
# ##### Question 2: How does revenue vary across different cities?

# %%
df.groupby('City')['gross income'].sum().round(2)
# Out:
# City
# Mandalay     5057.03
# Naypyitaw    5265.18
# Yangon       5057.16
# Name: gross income, dtype: float64

# %%
revenue_per_city = df.groupby('City')['gross income'].sum().round(2)

# %%
fig = revenue_per_city.plot.bar()
fig.set_title('Revenue by City')
fig.set_xlabel('City')
fig.set_ylabel('Revenue (USD)')
# Out:
# Text(0, 0.5, 'Revenue (USD)')

# %% [markdown]
# ##### Question 3: What is the distribution of customer types (Member vs. Normal)?

# %%
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
customer_type = df['Customer type'].value_counts()
fig = customer_type.plot.pie(autopct='%1.1f%%', labels = ['Member', 'Normal'])
fig.set_ylabel('')
fig.set_title('Customer type distribution')
# Out:
# Text(0.5, 1.0, 'Customer type distribution')

# %% [markdown]
# ##### Question 4: How does gender affect purchase behavior and total sales?

# %%
df.groupby('Gender')['Total'].mean().round(2)
#Average amount spent per sale by gender
# Out:
# Gender
# Female    335.10
# Male      310.79
# Name: Total, dtype: float64

# %%
df.groupby('Gender')['Total'].sum().round(2)
#Total amount spent on sales by gender
# Out:
# Gender
# Female    167882.92
# Male      155083.82
# Name: Total, dtype: float64
